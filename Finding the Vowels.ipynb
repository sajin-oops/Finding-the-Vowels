# %%
vowels = "aeiou"
name = "sajin"
count = 0

# %%
for char in vowels:
    if char in name:
        count += 1

# %%
# Out:
# 2

# %%
# Count vowels 

vowels = "aeiou"
name = "saaajiin"
count = 0
for char in name:
    if char in vowels:
        count += 1
        print(char)
        
print("No of vowels in name",count)
# Out:
# a
# a
# a
# i
# i
# No of vowels in name 5
